# %%
import torch

# %%
check = torch.load('/scratch2/mrenaudin/colorlessgreenRNNs/checkpoints/lstm_adam/epoch_20.pt', map_location='cpu')

# %%
check['optimizer_state_dict']
# Out:
# {'state': {0: {'step': tensor(9270.),
#    'exp_avg': tensor([[ 2.5485e-06, -1.1256e-06, -1.6560e-06,  ...,  4.6290e-06,
#             -2.3764e-06, -5.3138e-07],
#            [ 1.2278e-06,  2.0528e-06,  3.0501e-07,  ...,  5.8000e-07,
#             -2.0176e-06, -4.1753e-07],
#            [ 2.1537e-05, -2.1350e-05, -1.6157e-05,  ..., -3.2629e-05,
#              1.4029e-05,  3.2906e-05],
#            ...,
#            [-1.3328e-18,  1.7088e-19,  1.1236e-18,  ..., -9.0768e-19,
#              4.4911e-19,  3.0216e-19],
#            [ 1.4892e-06, -8.0769e-08,  1.0036e-07,  ...,  1.7394e-06,
#             -1.2475e-06,  1.6667e-07],
#            [ 5.4275e-13, -8.0350e-14,  1.0687e-13,  ...,  1.0793e-19,
#             -1.8174e-13, -2.2228e-14]]),
#    'exp_avg_sq': tensor([[3.4939e-10, 3.1507e-10, 3.1152e-10,  ..., 2.9565e-10, 2.8413e-10,
#             3.0762e-10],
#            [7.5596e-11, 8.4007e-11, 8.6190e-11,  ..., 8.5850e-11, 8.9491e-11,
#             9.1577e-11],
# ...

# %%
check[optimizer_state_dict]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 check[optimizer_state_dict]
#
# NameError: name 'optimizer_state_dict' is not defined
