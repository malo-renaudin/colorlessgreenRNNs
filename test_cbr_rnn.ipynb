# %%
import torch.nn as nn
import torch.utils.data.dataloader
from torch.nn.functional import scaled_dot_product_attention
import numpy as np
from src.language_models.utils import repackage_hidden, get_batch, batchify, save_checkpoint, move_to_device, save_val_loss_data
from src.language_models.dictionary_corpus import Corpus
from tqdm import tqdm

# %% [markdown]
# # Model

# %%
class CBR_RNN(nn.Module): 
# goal here is to reuse CBR_RNN but with scaled dot product attention for more efficient computations. 
# Also I got rid of options such as loading pretrained embeddings, and ablating attention to simplify the code.
# In the future if those options are needed, they can still be copy pasted from William's code as the structure hasn't changed
    def __init__(self, ntoken, ninp, nhid, dropout=0.5, device=None):
        super().__init__()
        #same layers as Timkey
        self.device = device
        self.tanh = nn.Tanh()
        self.drop = nn.Dropout(dropout)
        self.score_attn = nn.Softmax(dim=-1)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.q = nn.Linear(ninp+nhid,nhid)
        self.intermediate_h = nn.Linear(nhid*4,nhid*4)
        self.decoder = nn.Linear(nhid, ntoken+1)
        self.q_norm = torch.nn.LayerNorm(nhid)
        self.int_norm = torch.nn.LayerNorm(nhid * 4)
        self.f_norm = torch.nn.LayerNorm(nhid * 3)  
        self.nhid = nhid
        self.attn_div_factor = np.sqrt(nhid)
        self.final_h = nn.Linear(nhid*4,nhid*3)
        
        
    #same weight initialization as Timkey
    def init_weights(self, freeze_embedding, aux_objective):
        """ Initialize encoder and decoder weights """
        initrange = 0.1
        if not freeze_embedding:
            self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.fill_(0)
        self.decoder.weight.data.uniform_(-initrange, initrange)
        if(aux_objective):
            self.aux_decoder.bias.data.fill_(0)
            self.aux_decoder.weight.data.uniform_(-initrange, initrange)

    
    def init_hidden(self, bsz):
        """ Initialize a fresh hidden state """
        weight = next(self.parameters()).data
    
        return torch.tensor(weight.new(bsz, self.nhid).zero_())
    
    def init_cache(self, observation):
        if len(observation.size())>1:
            bsz = observation.size(dim=-1)
        else:
            bsz = 1
        seq_len = observation.size(dim=0)

        return torch.zeros(1, bsz, self.nhid).to(self.device), torch.zeros(1, bsz, self.nhid).to(self.device), torch.zeros(1, bsz, self.nhid).to(self.device)


    def forward(self, observation, initial_cache, attention_mask=None):
        # Get dimensions
        seq_len = observation.size(0) #if len(observation.size()) > 1 else 1
        # Unpack initial cache
        hidden, key_cache, value_cache = initial_cache

        # 1. Encode observations
        emb = self.drop(self.encoder(observation))
        # Process sequence : is there another more efficient way to compute causal attention than looping ?
        for i in range(seq_len): #need to keep sequential processing as the core structure is recurrent (each new word needs the hidden state obtained after prediction of the last word)
            # 2. Concatenate with previous hidden state
            
            query = self.drop(self.tanh(self.q_norm(self.q(torch.cat((emb[i],hidden[i]), -1))))) #b * d
            query = query.unsqueeze(1) 
            print('query', query.shape)
            print('key_cache', key_cache.shape)
            print('value_cache', value_cache.shape)
            #What should be the shape of each input to this function
            attn_output = scaled_dot_product_attention(
                query, key_cache.transpose(0, 1), value_cache.transpose(0, 1),#batch dimension needs to be the first one, hence the transpose (and the unsuqeeze on the query), second dim is seq len
                is_causal=True
            )
            attn = attn_output.squeeze(1)
            print('attn', attn.shape)
            print('emb[i]', emb[i].shape)
            print('query.squeeze(1)', query.squeeze(1).shape)
            print('hidden[i]', hidden[i].shape)
            print('concat', torch.cat((emb[i],query.squeeze(1),attn,hidden[i]),-1).shape)
          
            intermediate = self.drop(self.tanh(self.int_norm(self.intermediate_h(torch.cat((emb[i],query.squeeze(1),attn,hidden[i]),-1)))))
            key_cache_i, value_cache_i, hidden_i = self.drop(self.tanh(self.f_norm(self.final_h(intermediate)))).split(self.nhid, dim=-1)
            
            hidden = torch.cat((hidden, hidden_i.unsqueeze(0)), dim=0)
            key_cache = torch.cat((key_cache, key_cache_i.unsqueeze(0)), dim=0)

            value_cache = torch.cat((value_cache, value_cache_i.unsqueeze(0)), dim=0)
          
        decoded = self.decoder(hidden[1:])
        
        return decoded, hidden

# %%
class Multihead_CBR_RNN(nn.Module): 
# goal here is to reuse CBR_RNN but with scaled dot product attention for more efficient computations. 
# Also I got rid of options such as loading pretrained embeddings, and ablating attention to simplify the code.
# In the future if those options are needed, they can still be copy pasted from William's code as the structure hasn't changed
    def __init__(self, ntoken, ninp, nhid, nheads, dropout=0.5, device=None):
        super().__init__()
        #same layers as Timkey
        self.device = device
        self.tanh = nn.Tanh()
        self.drop = nn.Dropout(dropout)
        self.score_attn = nn.Softmax(dim=-1)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.q = nn.Linear(ninp+nhid,nhid)
        self.intermediate_h = nn.Linear(nhid*4,nhid*4)
        self.decoder = nn.Linear(nhid, ntoken+1)
        self.q_norm = torch.nn.LayerNorm(nhid)
        self.int_norm = torch.nn.LayerNorm(nhid * 4)
        self.f_norm = torch.nn.LayerNorm(nhid * 3)  
        self.nhid = nhid
        self.attn_div_factor = np.sqrt(nhid)
        self.final_h = nn.Linear(nhid*4,nhid*3)
        self.multihead_attn = nn.MultiheadAttention(embed_dim=nhid, num_heads=nheads, batch_first=True)
        self.nheads = nheads

        
    #same weight initialization as Timkey
    def init_weights(self, freeze_embedding, aux_objective):
        """ Initialize encoder and decoder weights """
        initrange = 0.1
        if not freeze_embedding:
            self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.fill_(0)
        self.decoder.weight.data.uniform_(-initrange, initrange)
        if(aux_objective):
            self.aux_decoder.bias.data.fill_(0)
            self.aux_decoder.weight.data.uniform_(-initrange, initrange)

    
    def init_hidden(self, bsz):
        """ Initialize a fresh hidden state """
        weight = next(self.parameters()).data
    
        return torch.tensor(weight.new(bsz, self.nhid).zero_())
    
    def init_cache(self, observation):
        if len(observation.size())>1:
            bsz = observation.size(dim=-1)
        else:
            bsz = 1
        seq_len = observation.size(dim=0)

        return torch.zeros(1, bsz, self.nhid).to(self.device), torch.zeros(1, bsz, self.nhid).to(self.device), torch.zeros(1, bsz, self.nhid).to(self.device)


    def forward(self, observation, initial_cache, nheads):
        # Get dimensions
        seq_len = observation.size(0) #if len(observation.size()) > 1 else 1
        # Unpack initial cache
        hidden, key_cache, value_cache = initial_cache
        seq = hidden.size(0)
        batch = hidden.size(1)
        nhid = hidden.size(2)
        # 1. Encode observations
        emb = self.drop(self.encoder(observation))
        # Process sequence : is there another more efficient way to compute causal attention than looping ?
        for i in range(seq_len): #need to keep sequential processing as the core structure is recurrent (each new word needs the hidden state obtained after prediction of the last word)
            # 2. Concatenate with previous hidden state
            print(i)
            query = self.drop(self.tanh(self.q_norm(self.q(torch.cat((emb[i],hidden[i]), -1))))) #b * d
            print('query', query.shape)
            print('key_cache', key_cache.shape)
            print('value_cache', value_cache.shape)
            query = query.unsqueeze(1) 
            #here multihead attention demands that the query be split wrt nb of heads. each split is processed in parallel, and the results are concatenated at the end.
            attn_output = self.multihead_attn(
                query, key_cache.transpose(0, 1), value_cache.transpose(0, 1)
                
            )
            #outputs attn output and attn output weights
            attn = attn_output[0]#.squeeze(1)
            print('emb[i].unsqueeze(0)', emb[i].unsqueeze(0).shape)
            print('query', query.shape)
            print('attn', attn.shape)
            print('hidden[i].unsqueeze(0)', hidden[i].unsqueeze(0).shape)
            print('concat', torch.cat((emb[i].unsqueeze(0),query.transpose(0, 1),attn.transpose(0, 1),hidden[i].unsqueeze(0)),-1).shape)
            intermediate = self.drop(self.tanh(self.int_norm(self.intermediate_h(torch.cat((emb[i].unsqueeze(0),query.transpose(0, 1),attn.transpose(0, 1),hidden[i].unsqueeze(0)),-1)))))
            print('intermediate', intermediate.shape)
            intermediate_2 = self.drop(self.tanh(self.f_norm(self.final_h(intermediate))))
            print('intermediate 2', intermediate_2.shape)
            key_cache_i, value_cache_i, hidden_i = intermediate_2.split(self.nhid, dim=-1)
            print('key_cache_i', key_cache_i.shape)
            print('value_cache_i', value_cache_i.shape)
            print('hidden_i', hidden_i .shape)
            hidden = torch.cat((hidden, hidden_i), dim=0)
            print('hidden', hidden.shape)
            key_cache = torch.cat((key_cache, key_cache_i), dim=0)
            print('key_cache', key_cache.shape)
            value_cache = torch.cat((value_cache, value_cache_i), dim=0)
            print('value_cache', value_cache.shape)
        print('hidden[1:]', hidden[1:].shape)
        decoded = self.decoder(hidden[1:])
        print('decoded', decoded.shape)
        
        return decoded, hidden

# %% [markdown]
# # Training function

# %%
def train(model, criterion, train_data, batch_size, ntokens, nheads=False):
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0
    #NEW : move hidden to devide
    hidden = model.init_hidden(batch_size)

    for batch, i in enumerate(tqdm(range(0, train_data.size(0) - 1, 35), desc="Training")):
        data, targets = get_batch(train_data, i, 35)
        #NEW : move data and target to device
        cache = model.init_cache(data)
        # truncated BPP
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, cache, nheads)
        output_flat = output.reshape(-1, output.size(-1))
        
        # Similarly, reshape targets to [seq_len*batch_size]
        targets_flat = targets.reshape(-1)
        #loss = criterion(output.view(-1, ntokens), targets)
        loss=criterion(output_flat, targets_flat)
        loss.backward()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.25)
        for p in model.parameters():
            p.data.add_(-10, p.grad.data)

        total_loss += loss.item()

# %% [markdown]
# # Data

# %%
corpus = Corpus('/scratch2/mrenaudin/colorlessgreenRNNs/english_data')

# %%
ntokens = len(corpus.dictionary)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
train_data = batchify(corpus.train, 128, device)#batch size of 128
val_data = batchify(corpus.valid, 128, device)
test_data = batchify(corpus.test, 128, device)

# %%
criterion = nn.CrossEntropyLoss()

# %%
model = CBR_RNN(ntokens, 128, 128) #ntokens, embedding size, nb of hidden units per layer

# %%
model = Multihead_CBR_RNN(ntokens, 128, 128, 2)

# %%
batch_size = 128

# %%
nheads = 2

# %%
train(model, criterion, train_data, batch_size, ntokens, nheads)
#in CBR_RNN : hidden, key_cache, and value_chache are [seq_len, batch_size, nb of hidden units per layer]
# Out:
# /tmp/ipykernel_3680725/1530358260.py:43: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(weight.new(bsz, self.nhid).zero_())
# Training:   0%|          | 0/18540 [00:00<?, ?it/s]
# 0
# query torch.Size([128, 128])
# key_cache torch.Size([1, 128, 128])
# value_cache torch.Size([1, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([2, 128, 128])
# key_cache torch.Size([2, 128, 128])
# value_cache torch.Size([2, 128, 128])
# 1
# query torch.Size([128, 128])
# key_cache torch.Size([2, 128, 128])
# value_cache torch.Size([2, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([3, 128, 128])
# key_cache torch.Size([3, 128, 128])
# value_cache torch.Size([3, 128, 128])
# 2
# query torch.Size([128, 128])
# key_cache torch.Size([3, 128, 128])
# value_cache torch.Size([3, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([4, 128, 128])
# key_cache torch.Size([4, 128, 128])
# value_cache torch.Size([4, 128, 128])
# 3
# query torch.Size([128, 128])
# key_cache torch.Size([4, 128, 128])
# value_cache torch.Size([4, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([5, 128, 128])
# key_cache torch.Size([5, 128, 128])
# value_cache torch.Size([5, 128, 128])
# 4
# query torch.Size([128, 128])
# key_cache torch.Size([5, 128, 128])
# value_cache torch.Size([5, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([6, 128, 128])
# key_cache torch.Size([6, 128, 128])
# value_cache torch.Size([6, 128, 128])
# 5
# query torch.Size([128, 128])
# key_cache torch.Size([6, 128, 128])
# value_cache torch.Size([6, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([7, 128, 128])
# key_cache torch.Size([7, 128, 128])
# value_cache torch.Size([7, 128, 128])
# 6
# query torch.Size([128, 128])
# key_cache torch.Size([7, 128, 128])
# value_cache torch.Size([7, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([8, 128, 128])
# key_cache torch.Size([8, 128, 128])
# value_cache torch.Size([8, 128, 128])
# 7
# query torch.Size([128, 128])
# key_cache torch.Size([8, 128, 128])
# value_cache torch.Size([8, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([9, 128, 128])
# key_cache torch.Size([9, 128, 128])
# value_cache torch.Size([9, 128, 128])
# 8
# query torch.Size([128, 128])
# key_cache torch.Size([9, 128, 128])
# value_cache torch.Size([9, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([10, 128, 128])
# key_cache torch.Size([10, 128, 128])
# value_cache torch.Size([10, 128, 128])
# 9
# query torch.Size([128, 128])
# key_cache torch.Size([10, 128, 128])
# value_cache torch.Size([10, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([11, 128, 128])
# key_cache torch.Size([11, 128, 128])
# value_cache torch.Size([11, 128, 128])
# 10
# query torch.Size([128, 128])
# key_cache torch.Size([11, 128, 128])
# value_cache torch.Size([11, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([12, 128, 128])
# key_cache torch.Size([12, 128, 128])
# value_cache torch.Size([12, 128, 128])
# 11
# query torch.Size([128, 128])
# key_cache torch.Size([12, 128, 128])
# value_cache torch.Size([12, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([13, 128, 128])
# key_cache torch.Size([13, 128, 128])
# value_cache torch.Size([13, 128, 128])
# 12
# query torch.Size([128, 128])
# key_cache torch.Size([13, 128, 128])
# value_cache torch.Size([13, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([14, 128, 128])
# key_cache torch.Size([14, 128, 128])
# value_cache torch.Size([14, 128, 128])
# 13
# query torch.Size([128, 128])
# key_cache torch.Size([14, 128, 128])
# value_cache torch.Size([14, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([15, 128, 128])
# key_cache torch.Size([15, 128, 128])
# value_cache torch.Size([15, 128, 128])
# 14
# query torch.Size([128, 128])
# key_cache torch.Size([15, 128, 128])
# value_cache torch.Size([15, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([16, 128, 128])
# key_cache torch.Size([16, 128, 128])
# value_cache torch.Size([16, 128, 128])
# 15
# query torch.Size([128, 128])
# key_cache torch.Size([16, 128, 128])
# value_cache torch.Size([16, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([17, 128, 128])
# key_cache torch.Size([17, 128, 128])
# value_cache torch.Size([17, 128, 128])
# 16
# query torch.Size([128, 128])
# key_cache torch.Size([17, 128, 128])
# value_cache torch.Size([17, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([18, 128, 128])
# key_cache torch.Size([18, 128, 128])
# value_cache torch.Size([18, 128, 128])
# 17
# query torch.Size([128, 128])
# key_cache torch.Size([18, 128, 128])
# value_cache torch.Size([18, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([19, 128, 128])
# key_cache torch.Size([19, 128, 128])
# value_cache torch.Size([19, 128, 128])
# 18
# query torch.Size([128, 128])
# key_cache torch.Size([19, 128, 128])
# value_cache torch.Size([19, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([20, 128, 128])
# key_cache torch.Size([20, 128, 128])
# value_cache torch.Size([20, 128, 128])
# 19
# query torch.Size([128, 128])
# key_cache torch.Size([20, 128, 128])
# value_cache torch.Size([20, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([21, 128, 128])
# key_cache torch.Size([21, 128, 128])
# value_cache torch.Size([21, 128, 128])
# 20
# query torch.Size([128, 128])
# key_cache torch.Size([21, 128, 128])
# value_cache torch.Size([21, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([22, 128, 128])
# key_cache torch.Size([22, 128, 128])
# value_cache torch.Size([22, 128, 128])
# 21
# query torch.Size([128, 128])
# key_cache torch.Size([22, 128, 128])
# value_cache torch.Size([22, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([23, 128, 128])
# key_cache torch.Size([23, 128, 128])
# value_cache torch.Size([23, 128, 128])
# 22
# query torch.Size([128, 128])
# key_cache torch.Size([23, 128, 128])
# value_cache torch.Size([23, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([24, 128, 128])
# key_cache torch.Size([24, 128, 128])
# value_cache torch.Size([24, 128, 128])
# 23
# query torch.Size([128, 128])
# key_cache torch.Size([24, 128, 128])
# value_cache torch.Size([24, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([25, 128, 128])
# key_cache torch.Size([25, 128, 128])
# value_cache torch.Size([25, 128, 128])
# 24
# query torch.Size([128, 128])
# key_cache torch.Size([25, 128, 128])
# value_cache torch.Size([25, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([26, 128, 128])
# key_cache torch.Size([26, 128, 128])
# value_cache torch.Size([26, 128, 128])
# 25
# query torch.Size([128, 128])
# key_cache torch.Size([26, 128, 128])
# value_cache torch.Size([26, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([27, 128, 128])
# key_cache torch.Size([27, 128, 128])
# value_cache torch.Size([27, 128, 128])
# 26
# query torch.Size([128, 128])
# key_cache torch.Size([27, 128, 128])
# value_cache torch.Size([27, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([28, 128, 128])
# key_cache torch.Size([28, 128, 128])
# value_cache torch.Size([28, 128, 128])
# 27
# query torch.Size([128, 128])
# key_cache torch.Size([28, 128, 128])
# value_cache torch.Size([28, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([29, 128, 128])
# key_cache torch.Size([29, 128, 128])
# value_cache torch.Size([29, 128, 128])
# 28
# query torch.Size([128, 128])
# key_cache torch.Size([29, 128, 128])
# value_cache torch.Size([29, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([30, 128, 128])
# key_cache torch.Size([30, 128, 128])
# value_cache torch.Size([30, 128, 128])
# 29
# query torch.Size([128, 128])
# key_cache torch.Size([30, 128, 128])
# value_cache torch.Size([30, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([31, 128, 128])
# key_cache torch.Size([31, 128, 128])
# value_cache torch.Size([31, 128, 128])
# 30
# query torch.Size([128, 128])
# key_cache torch.Size([31, 128, 128])
# value_cache torch.Size([31, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([32, 128, 128])
# key_cache torch.Size([32, 128, 128])
# value_cache torch.Size([32, 128, 128])
# 31
# query torch.Size([128, 128])
# key_cache torch.Size([32, 128, 128])
# value_cache torch.Size([32, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([33, 128, 128])
# key_cache torch.Size([33, 128, 128])
# value_cache torch.Size([33, 128, 128])
# 32
# query torch.Size([128, 128])
# key_cache torch.Size([33, 128, 128])
# value_cache torch.Size([33, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([34, 128, 128])
# key_cache torch.Size([34, 128, 128])
# value_cache torch.Size([34, 128, 128])
# 33
# query torch.Size([128, 128])
# key_cache torch.Size([34, 128, 128])
# value_cache torch.Size([34, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([35, 128, 128])
# key_cache torch.Size([35, 128, 128])
# value_cache torch.Size([35, 128, 128])
# 34
# query torch.Size([128, 128])
# key_cache torch.Size([35, 128, 128])
# value_cache torch.Size([35, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([36, 128, 128])
# key_cache torch.Size([36, 128, 128])
# value_cache torch.Size([36, 128, 128])
# hidden[1:] torch.Size([35, 128, 128])
# decoded torch.Size([35, 128, 50002])
# Training:   0%|          | 1/18540 [00:00<4:08:19,  1.24it/s]
# 0
# query torch.Size([128, 128])
# key_cache torch.Size([1, 128, 128])
# value_cache torch.Size([1, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([2, 128, 128])
# key_cache torch.Size([2, 128, 128])
# value_cache torch.Size([2, 128, 128])
# 1
# query torch.Size([128, 128])
# key_cache torch.Size([2, 128, 128])
# value_cache torch.Size([2, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([3, 128, 128])
# key_cache torch.Size([3, 128, 128])
# value_cache torch.Size([3, 128, 128])
# 2
# query torch.Size([128, 128])
# key_cache torch.Size([3, 128, 128])
# value_cache torch.Size([3, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([4, 128, 128])
# key_cache torch.Size([4, 128, 128])
# value_cache torch.Size([4, 128, 128])
# 3
# query torch.Size([128, 128])
# key_cache torch.Size([4, 128, 128])
# value_cache torch.Size([4, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([5, 128, 128])
# key_cache torch.Size([5, 128, 128])
# value_cache torch.Size([5, 128, 128])
# 4
# query torch.Size([128, 128])
# key_cache torch.Size([5, 128, 128])
# value_cache torch.Size([5, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([6, 128, 128])
# key_cache torch.Size([6, 128, 128])
# value_cache torch.Size([6, 128, 128])
# 5
# query torch.Size([128, 128])
# key_cache torch.Size([6, 128, 128])
# value_cache torch.Size([6, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([7, 128, 128])
# key_cache torch.Size([7, 128, 128])
# value_cache torch.Size([7, 128, 128])
# 6
# query torch.Size([128, 128])
# key_cache torch.Size([7, 128, 128])
# value_cache torch.Size([7, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([8, 128, 128])
# key_cache torch.Size([8, 128, 128])
# value_cache torch.Size([8, 128, 128])
# 7
# query torch.Size([128, 128])
# key_cache torch.Size([8, 128, 128])
# value_cache torch.Size([8, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([9, 128, 128])
# key_cache torch.Size([9, 128, 128])
# value_cache torch.Size([9, 128, 128])
# 8
# query torch.Size([128, 128])
# key_cache torch.Size([9, 128, 128])
# value_cache torch.Size([9, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([10, 128, 128])
# key_cache torch.Size([10, 128, 128])
# value_cache torch.Size([10, 128, 128])
# 9
# query torch.Size([128, 128])
# key_cache torch.Size([10, 128, 128])
# value_cache torch.Size([10, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([11, 128, 128])
# key_cache torch.Size([11, 128, 128])
# value_cache torch.Size([11, 128, 128])
# 10
# query torch.Size([128, 128])
# key_cache torch.Size([11, 128, 128])
# value_cache torch.Size([11, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([12, 128, 128])
# key_cache torch.Size([12, 128, 128])
# value_cache torch.Size([12, 128, 128])
# 11
# query torch.Size([128, 128])
# key_cache torch.Size([12, 128, 128])
# value_cache torch.Size([12, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([13, 128, 128])
# key_cache torch.Size([13, 128, 128])
# value_cache torch.Size([13, 128, 128])
# 12
# query torch.Size([128, 128])
# key_cache torch.Size([13, 128, 128])
# value_cache torch.Size([13, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([14, 128, 128])
# key_cache torch.Size([14, 128, 128])
# value_cache torch.Size([14, 128, 128])
# 13
# query torch.Size([128, 128])
# key_cache torch.Size([14, 128, 128])
# value_cache torch.Size([14, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([15, 128, 128])
# key_cache torch.Size([15, 128, 128])
# value_cache torch.Size([15, 128, 128])
# 14
# query torch.Size([128, 128])
# key_cache torch.Size([15, 128, 128])
# value_cache torch.Size([15, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([16, 128, 128])
# key_cache torch.Size([16, 128, 128])
# value_cache torch.Size([16, 128, 128])
# 15
# query torch.Size([128, 128])
# key_cache torch.Size([16, 128, 128])
# value_cache torch.Size([16, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([17, 128, 128])
# key_cache torch.Size([17, 128, 128])
# value_cache torch.Size([17, 128, 128])
# 16
# query torch.Size([128, 128])
# key_cache torch.Size([17, 128, 128])
# value_cache torch.Size([17, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([18, 128, 128])
# key_cache torch.Size([18, 128, 128])
# value_cache torch.Size([18, 128, 128])
# 17
# query torch.Size([128, 128])
# key_cache torch.Size([18, 128, 128])
# value_cache torch.Size([18, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([19, 128, 128])
# key_cache torch.Size([19, 128, 128])
# value_cache torch.Size([19, 128, 128])
# 18
# query torch.Size([128, 128])
# key_cache torch.Size([19, 128, 128])
# value_cache torch.Size([19, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([20, 128, 128])
# key_cache torch.Size([20, 128, 128])
# value_cache torch.Size([20, 128, 128])
# 19
# query torch.Size([128, 128])
# key_cache torch.Size([20, 128, 128])
# value_cache torch.Size([20, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([21, 128, 128])
# key_cache torch.Size([21, 128, 128])
# value_cache torch.Size([21, 128, 128])
# 20
# query torch.Size([128, 128])
# key_cache torch.Size([21, 128, 128])
# value_cache torch.Size([21, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([22, 128, 128])
# key_cache torch.Size([22, 128, 128])
# value_cache torch.Size([22, 128, 128])
# 21
# query torch.Size([128, 128])
# key_cache torch.Size([22, 128, 128])
# value_cache torch.Size([22, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([23, 128, 128])
# key_cache torch.Size([23, 128, 128])
# value_cache torch.Size([23, 128, 128])
# 22
# query torch.Size([128, 128])
# key_cache torch.Size([23, 128, 128])
# value_cache torch.Size([23, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([24, 128, 128])
# key_cache torch.Size([24, 128, 128])
# value_cache torch.Size([24, 128, 128])
# 23
# query torch.Size([128, 128])
# key_cache torch.Size([24, 128, 128])
# value_cache torch.Size([24, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([25, 128, 128])
# key_cache torch.Size([25, 128, 128])
# value_cache torch.Size([25, 128, 128])
# 24
# query torch.Size([128, 128])
# key_cache torch.Size([25, 128, 128])
# value_cache torch.Size([25, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([26, 128, 128])
# key_cache torch.Size([26, 128, 128])
# value_cache torch.Size([26, 128, 128])
# 25
# query torch.Size([128, 128])
# key_cache torch.Size([26, 128, 128])
# value_cache torch.Size([26, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([27, 128, 128])
# key_cache torch.Size([27, 128, 128])
# value_cache torch.Size([27, 128, 128])
# 26
# query torch.Size([128, 128])
# key_cache torch.Size([27, 128, 128])
# value_cache torch.Size([27, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([28, 128, 128])
# key_cache torch.Size([28, 128, 128])
# value_cache torch.Size([28, 128, 128])
# 27
# query torch.Size([128, 128])
# key_cache torch.Size([28, 128, 128])
# value_cache torch.Size([28, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([29, 128, 128])
# key_cache torch.Size([29, 128, 128])
# value_cache torch.Size([29, 128, 128])
# 28
# query torch.Size([128, 128])
# key_cache torch.Size([29, 128, 128])
# value_cache torch.Size([29, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([30, 128, 128])
# key_cache torch.Size([30, 128, 128])
# value_cache torch.Size([30, 128, 128])
# 29
# query torch.Size([128, 128])
# key_cache torch.Size([30, 128, 128])
# value_cache torch.Size([30, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([31, 128, 128])
# key_cache torch.Size([31, 128, 128])
# value_cache torch.Size([31, 128, 128])
# 30
# query torch.Size([128, 128])
# key_cache torch.Size([31, 128, 128])
# value_cache torch.Size([31, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([32, 128, 128])
# key_cache torch.Size([32, 128, 128])
# value_cache torch.Size([32, 128, 128])
# 31
# query torch.Size([128, 128])
# key_cache torch.Size([32, 128, 128])
# value_cache torch.Size([32, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([33, 128, 128])
# key_cache torch.Size([33, 128, 128])
# value_cache torch.Size([33, 128, 128])
# 32
# query torch.Size([128, 128])
# key_cache torch.Size([33, 128, 128])
# value_cache torch.Size([33, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([34, 128, 128])
# key_cache torch.Size([34, 128, 128])
# value_cache torch.Size([34, 128, 128])
# 33
# query torch.Size([128, 128])
# key_cache torch.Size([34, 128, 128])
# value_cache torch.Size([34, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([35, 128, 128])
# key_cache torch.Size([35, 128, 128])
# value_cache torch.Size([35, 128, 128])
# 34
# query torch.Size([128, 128])
# key_cache torch.Size([35, 128, 128])
# value_cache torch.Size([35, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([36, 128, 128])
# key_cache torch.Size([36, 128, 128])
# value_cache torch.Size([36, 128, 128])
# hidden[1:] torch.Size([35, 128, 128])
# decoded torch.Size([35, 128, 50002])
# Training:   0%|          | 2/18540 [00:01<4:03:04,  1.27it/s]
# 0
# query torch.Size([128, 128])
# key_cache torch.Size([1, 128, 128])
# value_cache torch.Size([1, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([2, 128, 128])
# key_cache torch.Size([2, 128, 128])
# value_cache torch.Size([2, 128, 128])
# 1
# query torch.Size([128, 128])
# key_cache torch.Size([2, 128, 128])
# value_cache torch.Size([2, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([3, 128, 128])
# key_cache torch.Size([3, 128, 128])
# value_cache torch.Size([3, 128, 128])
# 2
# query torch.Size([128, 128])
# key_cache torch.Size([3, 128, 128])
# value_cache torch.Size([3, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([4, 128, 128])
# key_cache torch.Size([4, 128, 128])
# value_cache torch.Size([4, 128, 128])
# 3
# query torch.Size([128, 128])
# key_cache torch.Size([4, 128, 128])
# value_cache torch.Size([4, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([5, 128, 128])
# key_cache torch.Size([5, 128, 128])
# value_cache torch.Size([5, 128, 128])
# 4
# query torch.Size([128, 128])
# key_cache torch.Size([5, 128, 128])
# value_cache torch.Size([5, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([6, 128, 128])
# key_cache torch.Size([6, 128, 128])
# value_cache torch.Size([6, 128, 128])
# 5
# query torch.Size([128, 128])
# key_cache torch.Size([6, 128, 128])
# value_cache torch.Size([6, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([7, 128, 128])
# key_cache torch.Size([7, 128, 128])
# value_cache torch.Size([7, 128, 128])
# 6
# query torch.Size([128, 128])
# key_cache torch.Size([7, 128, 128])
# value_cache torch.Size([7, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([8, 128, 128])
# key_cache torch.Size([8, 128, 128])
# value_cache torch.Size([8, 128, 128])
# 7
# query torch.Size([128, 128])
# key_cache torch.Size([8, 128, 128])
# value_cache torch.Size([8, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([9, 128, 128])
# key_cache torch.Size([9, 128, 128])
# value_cache torch.Size([9, 128, 128])
# 8
# query torch.Size([128, 128])
# key_cache torch.Size([9, 128, 128])
# value_cache torch.Size([9, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([10, 128, 128])
# key_cache torch.Size([10, 128, 128])
# ...
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([11, 128, 128])
# key_cache torch.Size([11, 128, 128])
# value_cache torch.Size([11, 128, 128])
# 10
# query torch.Size([128, 128])
# key_cache torch.Size([11, 128, 128])
# value_cache torch.Size([11, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([12, 128, 128])
# key_cache torch.Size([12, 128, 128])
# value_cache torch.Size([12, 128, 128])
# 11
# query torch.Size([128, 128])
# key_cache torch.Size([12, 128, 128])
# value_cache torch.Size([12, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([13, 128, 128])
# key_cache torch.Size([13, 128, 128])
# value_cache torch.Size([13, 128, 128])
# 12
# query torch.Size([128, 128])
# key_cache torch.Size([13, 128, 128])
# value_cache torch.Size([13, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([14, 128, 128])
# key_cache torch.Size([14, 128, 128])
# value_cache torch.Size([14, 128, 128])
# 13
# query torch.Size([128, 128])
# key_cache torch.Size([14, 128, 128])
# value_cache torch.Size([14, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([15, 128, 128])
# key_cache torch.Size([15, 128, 128])
# value_cache torch.Size([15, 128, 128])
# 14
# query torch.Size([128, 128])
# key_cache torch.Size([15, 128, 128])
# value_cache torch.Size([15, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([16, 128, 128])
# key_cache torch.Size([16, 128, 128])
# value_cache torch.Size([16, 128, 128])
# 15
# query torch.Size([128, 128])
# key_cache torch.Size([16, 128, 128])
# value_cache torch.Size([16, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([17, 128, 128])
# key_cache torch.Size([17, 128, 128])
# value_cache torch.Size([17, 128, 128])
# 16
# query torch.Size([128, 128])
# key_cache torch.Size([17, 128, 128])
# value_cache torch.Size([17, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([18, 128, 128])
# key_cache torch.Size([18, 128, 128])
# value_cache torch.Size([18, 128, 128])
# 17
# query torch.Size([128, 128])
# key_cache torch.Size([18, 128, 128])
# value_cache torch.Size([18, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([19, 128, 128])
# key_cache torch.Size([19, 128, 128])
# value_cache torch.Size([19, 128, 128])
# 18
# query torch.Size([128, 128])
# key_cache torch.Size([19, 128, 128])
# value_cache torch.Size([19, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([20, 128, 128])
# key_cache torch.Size([20, 128, 128])
# value_cache torch.Size([20, 128, 128])
# 19
# query torch.Size([128, 128])
# key_cache torch.Size([20, 128, 128])
# value_cache torch.Size([20, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([21, 128, 128])
# key_cache torch.Size([21, 128, 128])
# value_cache torch.Size([21, 128, 128])
# 20
# query torch.Size([128, 128])
# key_cache torch.Size([21, 128, 128])
# value_cache torch.Size([21, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([22, 128, 128])
# key_cache torch.Size([22, 128, 128])
# value_cache torch.Size([22, 128, 128])
# 21
# query torch.Size([128, 128])
# key_cache torch.Size([22, 128, 128])
# value_cache torch.Size([22, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([23, 128, 128])
# key_cache torch.Size([23, 128, 128])
# value_cache torch.Size([23, 128, 128])
# 22
# query torch.Size([128, 128])
# key_cache torch.Size([23, 128, 128])
# value_cache torch.Size([23, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([24, 128, 128])
# key_cache torch.Size([24, 128, 128])
# value_cache torch.Size([24, 128, 128])
# 23
# query torch.Size([128, 128])
# key_cache torch.Size([24, 128, 128])
# value_cache torch.Size([24, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([25, 128, 128])
# key_cache torch.Size([25, 128, 128])
# value_cache torch.Size([25, 128, 128])
# 24
# query torch.Size([128, 128])
# key_cache torch.Size([25, 128, 128])
# value_cache torch.Size([25, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([26, 128, 128])
# key_cache torch.Size([26, 128, 128])
# value_cache torch.Size([26, 128, 128])
# 25
# query torch.Size([128, 128])
# key_cache torch.Size([26, 128, 128])
# value_cache torch.Size([26, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([27, 128, 128])
# key_cache torch.Size([27, 128, 128])
# value_cache torch.Size([27, 128, 128])
# 26
# query torch.Size([128, 128])
# key_cache torch.Size([27, 128, 128])
# value_cache torch.Size([27, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([28, 128, 128])
# key_cache torch.Size([28, 128, 128])
# value_cache torch.Size([28, 128, 128])
# 27
# query torch.Size([128, 128])
# key_cache torch.Size([28, 128, 128])
# value_cache torch.Size([28, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([29, 128, 128])
# key_cache torch.Size([29, 128, 128])
# value_cache torch.Size([29, 128, 128])
# 28
# query torch.Size([128, 128])
# key_cache torch.Size([29, 128, 128])
# value_cache torch.Size([29, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([30, 128, 128])
# key_cache torch.Size([30, 128, 128])
# value_cache torch.Size([30, 128, 128])
# 29
# query torch.Size([128, 128])
# key_cache torch.Size([30, 128, 128])
# value_cache torch.Size([30, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([31, 128, 128])
# key_cache torch.Size([31, 128, 128])
# value_cache torch.Size([31, 128, 128])
# 30
# query torch.Size([128, 128])
# key_cache torch.Size([31, 128, 128])
# value_cache torch.Size([31, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([32, 128, 128])
# key_cache torch.Size([32, 128, 128])
# value_cache torch.Size([32, 128, 128])
# 31
# query torch.Size([128, 128])
# key_cache torch.Size([32, 128, 128])
# value_cache torch.Size([32, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([33, 128, 128])
# key_cache torch.Size([33, 128, 128])
# value_cache torch.Size([33, 128, 128])
# 32
# query torch.Size([128, 128])
# key_cache torch.Size([33, 128, 128])
# value_cache torch.Size([33, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([34, 128, 128])
# key_cache torch.Size([34, 128, 128])
# value_cache torch.Size([34, 128, 128])
# 33
# query torch.Size([128, 128])
# key_cache torch.Size([34, 128, 128])
# value_cache torch.Size([34, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([35, 128, 128])
# key_cache torch.Size([35, 128, 128])
# value_cache torch.Size([35, 128, 128])
# 34
# query torch.Size([128, 128])
# key_cache torch.Size([35, 128, 128])
# value_cache torch.Size([35, 128, 128])
# emb[i].unsqueeze(0) torch.Size([1, 128, 128])
# query torch.Size([128, 1, 128])
# attn torch.Size([128, 1, 128])
# hidden[i].unsqueeze(0) torch.Size([1, 128, 128])
# concat torch.Size([1, 128, 512])
# intermediate torch.Size([1, 128, 512])
# intermediate 2 torch.Size([1, 128, 384])
# key_cache_i torch.Size([1, 128, 128])
# value_cache_i torch.Size([1, 128, 128])
# hidden_i torch.Size([1, 128, 128])
# hidden torch.Size([36, 128, 128])
# key_cache torch.Size([36, 128, 128])
# value_cache torch.Size([36, 128, 128])
# hidden[1:] torch.Size([35, 128, 128])
# decoded torch.Size([35, 128, 50002])
# Training:   0%|          | 8/18540 [00:06<4:14:12,  1.22it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 train(model, criterion, train_data, batch_size, ntokens, nheads)
#
# Cell In[39], line 19, in train(model, criterion, train_data, batch_size, ntokens, nheads)
#      16 output_flat = output.reshape(-1, output.size(-1))
#      18 # Similarly, reshape targets to [seq_len*batch_size]
# ---> 19 targets_flat = targets.reshape(-1)
#      20 #loss = criterion(output.view(-1, ntokens), targets)
#      21 loss=criterion(output_flat, targets_flat)
#
# KeyboardInterrupt:
